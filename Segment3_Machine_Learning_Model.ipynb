# %%
# Add the dependencies
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import time
from sqlalchemy import create_engine
from config import db_password

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/NBA_Draft_db"
engine = create_engine(db_string)

# %%
nba_players_df = pd.read_sql('SELECT * FROM "nba_players_college_index"', con=engine)
nba_players_df
# Out:
#                player   season  age   tm    ws  games  gs    mp    mppg   fg  \
# 0        LeBron James  2008-09   24  CLE  20.3     81  81  3054  37.704  789
# 1        LeBron James  2012-13   28  MIA  19.3     76  76  2877  37.855  765
# 2        Kevin Durant  2013-14   25  OKC  19.2     81  81  3122  38.543  849
# 3        Kevin Durant  2012-13   24  OKC  18.9     81  81  3119  38.506  731
# 4        LeBron James  2009-10   25  CLE  18.5     76  76  2966  39.026  768
# ...               ...      ...  ...  ...   ...    ...  ..   ...     ...  ...
# 8097       Kevin Knox  2018-19   19  NYK  -1.3     75  57  2158  28.773  338
# 8098  Michael Beasley  2012-13   24  PHO  -1.5     75  20  1554  20.720  310
# 8099    Adam Morrison  2006-07   22  CHA  -1.5     78  23  2326  29.821  355
# 8100     Josh Jackson  2018-19   21  PHO  -1.7     79  29  1988  25.165  347
# 8101  Emmanuel Mudiay  2015-16   19  DEN  -2.1     68  66  2068  30.412  329
#
#       ...       l  w_l_pct    srs   sos    ap  creg  ctrn  ncaa    ff   nc
# 0     ...     NaN      NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 1     ...     NaN      NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 2     ...  1099.0    0.623   6.48  3.73  11.0  25.0   2.0  34.0   3.0  0.0
# 3     ...  1099.0    0.623   6.48  3.73  11.0  25.0   2.0  34.0   3.0  0.0
# 4     ...     NaN      NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# ...   ...     ...      ...    ...   ...   ...   ...   ...   ...   ...  ...
# 8097  ...   717.0    0.764  17.50  6.69  53.0  56.0  33.0  59.0  17.0  8.0
# 8098  ...  1179.0    0.586  10.14  6.23  16.0  19.0   2.0  31.0   4.0  0.0
# 8099  ...   702.0    0.656   3.57 -0.11  13.0  25.0  18.0  22.0   1.0  0.0
# 8100  ...   863.0    0.728  15.72  7.09  45.0  62.0  15.0  48.0  15.0  3.0
# 8101  ...     NaN      NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
#
# [8102 rows x 63 columns]

# %%
# Create outcome column 
nba_players_df.loc[nba_players_df['mppg'] >= 24, 'MPPG_Status'] = 'Successful'
nba_players_df.loc[nba_players_df['mppg'] < 24, 'MPPG_Status'] = 'Not Successful'

# %%
# Drop columns
nba_players_df = nba_players_df.drop(columns=[
    'player', 'season', 'tm', 'mppg', 'college', 'country', 'twop', 'threep', 'threepa', 'orb', 'drb', 'trb',
    'blk', 'fgpct', 'player_weight_kg', 'draft_number', 'from_', 'to_', 'yrs', 'school_games', 'w', 'l', 'w_l_pct', 'srs',
    'sos', 'creg', 'ff', 'nc'])
nba_players_df
# Out:
#       age    ws  games  gs    mp   fg   fga  twopa   ft  fta  ...  net_rating  \
# 0      24  20.3     81  81  3054  789  1613   1229  594  762  ...        14.7
# 1      28  19.3     76  76  2877  765  1354   1100  403  535  ...        14.1
# 2      25  19.2     81  81  3122  849  1688   1197  703  805  ...         8.0
# 3      24  18.9     81  81  3119  731  1433   1099  679  750  ...        12.7
# 4      25  18.5     76  76  2966  768  1528   1141  593  773  ...        10.8
# ...   ...   ...    ...  ..   ...  ...   ...    ...  ...  ...  ...         ...
# 8097   19  -1.3     75  57  2158  338   914    550  162  226  ...       -13.6
# 8098   24  -1.5     75  20  1554  310   766    622   94  126  ...       -11.5
# 8099   22  -1.5     78  23  2326  355   944    686  120  169  ...        -7.0
# 8100   21  -1.7     79  29  1988  347   841    616  143  213  ...        -9.6
# 8101   19  -2.1     68  66  2068  329   905    673  140  209  ...        -3.7
#
#       oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct    ap  ctrn  ncaa  \
# 0        0.042     0.189    0.334   0.591    0.365   NaN   NaN   NaN
# 1        0.044     0.208    0.298   0.640    0.344   NaN   NaN   NaN
# 2        0.022     0.184    0.327   0.635    0.259  11.0   2.0  34.0
# 3        0.018     0.201    0.298   0.647    0.213  11.0   2.0  34.0
# 4        0.030     0.185    0.333   0.604    0.398   NaN   NaN   NaN
# ...        ...       ...      ...     ...      ...   ...   ...   ...
# 8097     0.025     0.120    0.219   0.475    0.060  53.0  33.0  59.0
# 8098     0.038     0.170    0.276   0.462    0.125  16.0   2.0  31.0
# 8099     0.026     0.092    0.220   0.450    0.121  13.0  18.0  22.0
# 8100     0.032     0.136    0.234   0.487    0.142  45.0  15.0  48.0
# 8101     0.017     0.107    0.253   0.437    0.281   NaN   NaN   NaN
#
#          MPPG_Status
# 0         Successful
# 1         Successful
# 2         Successful
# 3         Successful
# 4         Successful
# ...              ...
# 8097      Successful
# 8098  Not Successful
# 8099      Successful
# 8100      Successful
# 8101      Successful
#
# [8102 rows x 36 columns]

# %%
# Replace Undrafted with 0
nba_players_df = nba_players_df.replace(['Undrafted'], 0)

# %%
# Convert draft year dtype
nba_players_df['draft_year'] = pd.to_datetime(nba_players_df['draft_year']).dt.year

# %%
# Convert draft_round and draft_numbers to int
nba_players_df['draft_round'] = nba_players_df['draft_round'].astype(str).astype(int)

# %%
# Replace null values with 0
nba_players_df = nba_players_df.fillna(0)

# %% [markdown]
# # Split data into training and testing

# %%
# Create our features
X = nba_players_df.drop('MPPG_Status', axis=1)

# Create our target
y = nba_players_df.MPPG_Status

# %%
X.describe()
# Out:
#                age           ws        games           gs           mp  \
# count  8102.000000  8102.000000  8102.000000  8102.000000  8102.000000
# mean     26.454703     2.587139    52.258578    25.250185  1221.235374
# std       4.260973     2.928076    24.925870    28.700144   883.636305
# min      18.000000    -2.100000     1.000000     0.000000     0.000000
# 25%      23.000000     0.300000    32.000000     1.000000   395.000000
# 50%      26.000000     1.700000    59.000000    11.000000  1149.500000
# 75%      29.000000     4.000000    74.000000    51.000000  1940.000000
# max      44.000000    20.300000    85.000000    83.000000  3424.000000
#
#                 fg          fga        twopa           ft          fta  ...  \
# count  8102.000000  8102.000000  8102.000000  8102.000000  8102.000000  ...
# mean    190.196988   418.245125   310.243890    91.737719   120.924957  ...
# std     170.460255   364.975022   290.862169   104.533303   131.985073  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      46.000000   109.000000    75.000000    17.000000    25.000000  ...
# 50%     150.000000   334.000000   230.000000    57.000000    78.000000  ...
# 75%     291.000000   641.750000   461.000000   129.000000   173.000000  ...
# max     978.000000  2173.000000  1655.000000   756.000000   916.000000  ...
#
#             astavg   net_rating     oreb_pct     dreb_pct      usg_pct  \
# count  8102.000000  8102.000000  8102.000000  8102.000000  8102.000000
# mean      1.797865    -2.119625     0.053012     0.143122     0.184605
# std       1.785011    11.863064     0.043991     0.064159     0.053724
# min       0.000000  -150.000000     0.000000     0.000000     0.000000
# 25%       0.600000    -6.200000     0.020000     0.097000     0.149000
# 50%       1.200000    -1.400000     0.039000     0.133000     0.181000
# 75%       2.400000     3.100000     0.081000     0.183000     0.217000
# max      11.700000   250.000000     1.000000     1.000000     0.750000
#
#             ts_pct      ast_pct           ap         ctrn         ncaa
# count  8102.000000  8102.000000  8102.000000  8102.000000  8102.000000
# mean      0.513358     0.129214    15.652185     6.337448    21.778450
# std       0.101590     0.093063    16.272734     8.421918    17.034088
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.484000     0.065000     0.000000     0.000000     5.000000
# 50%       0.527000     0.101000    11.000000     4.000000    21.000000
# 75%       0.563000     0.175000    24.000000     7.000000    33.000000
# max       1.500000     1.000000    53.000000    33.000000    59.000000
#
# [8 rows x 35 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# Not Successful    5072
# Successful        3030
# Name: MPPG_Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
Counter(y_train)
# Out:
# Counter({'Successful': 2305, 'Not Successful': 3771})

# %% [markdown]
# # Scale data

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

brf_model = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
brf_model.fit(X_train_scaled, y_train)
y_pred = brf_model.predict(X_test_scaled)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9613050968750828

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[1238,   63],
#        [  21,  704]])

# %%
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                       pre       rec       spe        f1       geo       iba       sup
#
# Not Successful       0.98      0.95      0.97      0.97      0.96      0.92      1301
#     Successful       0.92      0.97      0.95      0.94      0.96      0.93       725
#
#    avg / total       0.96      0.96      0.96      0.96      0.96      0.92      2026

# %%
# List the features sorted in descending order by feature importance
sorted(zip(brf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.16118549717868016, 'ptsavg'),
#  (0.12032557931215035, 'mp'),
#  (0.08834827334725634, 'pts'),
#  (0.08717847755060976, 'gs'),
#  (0.07072082333976039, 'fga'),
#  (0.06717374010577293, 'fg'),
#  (0.04298742072796433, 'twopa'),
#  (0.04240099587128124, 'tov'),
#  (0.03560857154797115, 'astavg'),
#  (0.03435687379709381, 'ft'),
#  (0.0333915975923025, 'fta'),
#  (0.029655973425840577, 'ast'),
#  (0.027628775375483552, 'stl'),
#  (0.026762426265732202, 'games'),
#  (0.025491459470104342, 'rebavg'),
#  (0.012724685742676307, 'usg_pct'),
#  (0.010873755818805937, 'ws'),
#  (0.010161749832617696, 'pf'),
#  (0.007521542024714461, 'ast_pct'),
#  (0.006228368029068777, 'oreb_pct'),
#  (0.005513015232821458, 'dreb_pct'),
#  (0.005135905326873097, 'twoppct'),
#  (0.005056541187443844, 'threeppct'),
#  (0.004994006879196242, 'tspct'),
#  (0.0049466561718229515, 'ftpct'),
#  (0.00464683750454261, 'ts_pct'),
#  (0.004575016215871109, 'net_rating'),
#  (0.004412216627928219, 'efgpct'),
#  (0.004273880051315638, 'age'),
#  (0.0035726638105787302, 'draft_year'),
#  (0.0033650193729377457, 'player_height_cm'),
#  (0.003069808935016315, 'ncaa'),
#  (0.002464927648459294, 'ap'),
#  (0.0023671124672090295, 'ctrn'),
#  (0.0008798062120968393, 'draft_round')]
