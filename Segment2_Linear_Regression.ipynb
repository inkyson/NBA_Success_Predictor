# %%
# Add the dependencies
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import time

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
import statsmodels.api as sm

# %% [markdown]
# ### Read in CSV and Perform Preliminary Data Preprocessing

# %%
# Loading data
file_path = Path("Resources/nba_players.csv")
nba_players_df = pd.read_csv(file_path)
nba_players_df
# Out:
#                Player   Season  Age   Tm    WS   G  GS    MP    MPPG   FG  \
# 0        LeBron James  2008-09   24  CLE  20.3  81  81  3054  37.704  789
# 1        LeBron James  2012-13   28  MIA  19.3  76  76  2877  37.855  765
# 2        Kevin Durant  2013-14   25  OKC  19.2  81  81  3122  38.543  849
# 3        Kevin Durant  2012-13   24  OKC  18.9  81  81  3119  38.506  731
# 4        LeBron James  2009-10   25  CLE  18.5  76  76  2966  39.026  768
# ...               ...      ...  ...  ...   ...  ..  ..   ...     ...  ...
# 8097       Kevin Knox  2018-19   19  NYK  -1.3  75  57  2158  28.773  338
# 8098  Michael Beasley  2012-13   24  PHO  -1.5  75  20  1554  20.720  310
# 8099    Adam Morrison  2006-07   22  CHA  -1.5  78  23  2326  29.821  355
# 8100     Josh Jackson  2018-19   21  PHO  -1.7  79  29  1988  25.165  347
# 8101  Emmanuel Mudiay  2015-16   19  DEN  -2.1  68  66  2068  30.412  329
#
#       ...  draft_number   pts  reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0     ...             1  28.4  7.6  7.2        14.7     0.042     0.189
# 1     ...             1  26.8  8.0  7.3        14.1     0.044     0.208
# 2     ...             2  32.0  7.4  5.5         8.0     0.022     0.184
# 3     ...             2  28.1  7.9  4.6        12.7     0.018     0.201
# 4     ...             1  29.7  7.3  8.6        10.8     0.030     0.185
# ...   ...           ...   ...  ...  ...         ...       ...       ...
# 8097  ...             9  12.8  4.5  1.1       -13.6     0.025     0.120
# 8098  ...             2  10.1  3.8  1.5       -11.5     0.038     0.170
# 8099  ...             3  11.8  2.9  2.1        -7.0     0.026     0.092
# 8100  ...             4  11.5  4.4  2.3        -9.6     0.032     0.136
# 8101  ...             7  12.8  3.4  5.5        -3.7     0.017     0.107
#
#       usg_pct  ts_pct  ast_pct
# 0       0.334   0.591    0.365
# 1       0.298   0.640    0.344
# 2       0.327   0.635    0.259
# 3       0.298   0.647    0.213
# 4       0.333   0.604    0.398
# ...       ...     ...      ...
# 8097    0.219   0.475    0.060
# 8098    0.276   0.462    0.125
# 8099    0.220   0.450    0.121
# 8100    0.234   0.487    0.142
# 8101    0.253   0.437    0.281
#
# [8102 rows x 48 columns]

# %%
# Create outcome column 
nba_players_df.loc[nba_players_df['MPPG'] >= 24, 'MPPG_Status'] = 'Successful'
nba_players_df.loc[nba_players_df['MPPG'] < 24, 'MPPG_Status'] = 'Not Successful'

# %%
# Drop columns
nba_players_df = nba_players_df.drop(columns=['Player', 'Season', 'Tm', 'college', 'country', 'MPPG_Status'])
nba_players_df
# Out:
#       Age    WS   G  GS    MP    MPPG   FG   FGA   2P   2PA  ...  \
# 0      24  20.3  81  81  3054  37.704  789  1613  657  1229  ...
# 1      28  19.3  76  76  2877  37.855  765  1354  662  1100  ...
# 2      25  19.2  81  81  3122  38.543  849  1688  657  1197  ...
# 3      24  18.9  81  81  3119  38.506  731  1433  592  1099  ...
# 4      25  18.5  76  76  2966  39.026  768  1528  639  1141  ...
# ...   ...   ...  ..  ..   ...     ...  ...   ...  ...   ...  ...
# 8097   19  -1.3  75  57  2158  28.773  338   914  213   550  ...
# 8098   24  -1.5  75  20  1554  20.720  310   766  265   622  ...
# 8099   22  -1.5  78  23  2326  29.821  355   944  268   686  ...
# 8100   21  -1.7  79  29  1988  25.165  347   841  274   616  ...
# 8101   19  -2.1  68  66  2068  30.412  329   905  255   673  ...
#
#       draft_number   pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  \
# 0                1  28.4  7.6  7.2        14.7     0.042     0.189    0.334
# 1                1  26.8  8.0  7.3        14.1     0.044     0.208    0.298
# 2                2  32.0  7.4  5.5         8.0     0.022     0.184    0.327
# 3                2  28.1  7.9  4.6        12.7     0.018     0.201    0.298
# 4                1  29.7  7.3  8.6        10.8     0.030     0.185    0.333
# ...            ...   ...  ...  ...         ...       ...       ...      ...
# 8097             9  12.8  4.5  1.1       -13.6     0.025     0.120    0.219
# 8098             2  10.1  3.8  1.5       -11.5     0.038     0.170    0.276
# 8099             3  11.8  2.9  2.1        -7.0     0.026     0.092    0.220
# 8100             4  11.5  4.4  2.3        -9.6     0.032     0.136    0.234
# 8101             7  12.8  3.4  5.5        -3.7     0.017     0.107    0.253
#
#       ts_pct  ast_pct
# 0      0.591    0.365
# 1      0.640    0.344
# 2      0.635    0.259
# 3      0.647    0.213
# 4      0.604    0.398
# ...      ...      ...
# 8097   0.475    0.060
# 8098   0.462    0.125
# 8099   0.450    0.121
# 8100   0.487    0.142
# 8101   0.437    0.281
#
# [8102 rows x 43 columns]

# %%
# Replace Undrafted with 0
nba_players_df = nba_players_df.replace(['Undrafted'], 0)

# %%
nba_players_df.draft_number.unique()
# Out:
# array(['1', '2', '5', '4', '7', '9', '3', '13', '15', '27', '30', '6',
#        '14', '35', '60', '10', '24', '41', '48', '25', '57', '43', '19',
#        '45', '33', '34', 0, '26', '47', '16', '18', '21', '32', '12',
#        '28', '23', '37', '17', '40', '11', '29', '8', '20', '55', '22',
#        '39', '46', '31', '38', '51', '56', '44', '36', '54', '52', '42',
#        '49', '53', '50', '58', '59', '82', '78'], dtype=object)

# %%
# Convert draft year dtype
nba_players_df['draft_year'] = pd.to_datetime(nba_players_df['draft_year']).dt.year

# %%
# Convert draft_round and draft_numbers to int
nba_players_df['draft_round'] = nba_players_df['draft_round'].astype(str).astype(int)
nba_players_df['draft_number'] = nba_players_df['draft_number'].astype(str).astype(int)

# %%
nba_players_df.dtypes
# Out:
# Age                   int64
# WS                  float64
# G                     int64
# GS                    int64
# MP                    int64
# MPPG                float64
# FG                    int64
# FGA                   int64
# 2P                    int64
# 2PA                   int64
# 3P                    int64
# 3PA                   int64
# FT                    int64
# FTA                   int64
# ORB                   int64
# DRB                   int64
# TRB                   int64
# AST                   int64
# STL                   int64
# BLK                   int64
# TOV                   int64
# PF                    int64
# PTS                   int64
# FG%                 float64
# 2P%                 float64
# 3P%                 float64
# eFG%                float64
# FT%                 float64
# TS%                 float64
# player_height_cm    float64
# player_weight_kg    float64
# draft_year            int64
# draft_round           int64
# draft_number          int64
# pts                 float64
# reb                 float64
# ast                 float64
# net_rating          float64
# oreb_pct            float64
# dreb_pct            float64
# usg_pct             float64
# ts_pct              float64
# ast_pct             float64
# dtype: object

# %%
# check for null values
nba_players_df.isnull().sum()
# Out:
# Age                    0
# WS                     0
# G                      0
# GS                     0
# MP                     0
# MPPG                   0
# FG                     0
# FGA                    0
# 2P                     0
# 2PA                    0
# 3P                     0
# 3PA                    0
# FT                     0
# FTA                    0
# ORB                    0
# DRB                    0
# TRB                    0
# AST                    0
# STL                    0
# BLK                    0
# TOV                    0
# PF                     0
# PTS                    0
# FG%                   28
# 2P%                   55
# 3P%                 1090
# eFG%                  28
# FT%                  290
# TS%                   27
# player_height_cm       0
# player_weight_kg       0
# draft_year             0
# draft_round            0
# draft_number           0
# pts                   15
# reb                   15
# ast                   15
# net_rating            15
# oreb_pct              15
# dreb_pct              15
# usg_pct               15
# ts_pct                15
# ast_pct               15
# dtype: int64

# %%
# Replace null values with 0
nba_players_df = nba_players_df.fillna(0)

# %%
# check for null values
nba_players_df.isnull().sum()
# Out:
# Age                 0
# WS                  0
# G                   0
# GS                  0
# MP                  0
# MPPG                0
# FG                  0
# FGA                 0
# 2P                  0
# 2PA                 0
# 3P                  0
# 3PA                 0
# FT                  0
# FTA                 0
# ORB                 0
# DRB                 0
# TRB                 0
# AST                 0
# STL                 0
# BLK                 0
# TOV                 0
# PF                  0
# PTS                 0
# FG%                 0
# 2P%                 0
# 3P%                 0
# eFG%                0
# FT%                 0
# TS%                 0
# player_height_cm    0
# player_weight_kg    0
# draft_year          0
# draft_round         0
# draft_number        0
# pts                 0
# reb                 0
# ast                 0
# net_rating          0
# oreb_pct            0
# dreb_pct            0
# usg_pct             0
# ts_pct              0
# ast_pct             0
# dtype: int64

# %% [markdown]
# ### Feature selection with linear regression

# %%
# Define features set
X = nba_players_df.copy()
X = X.drop("MPPG", axis=1)
X.head()
# Out:
#    Age    WS   G  GS    MP   FG   FGA   2P   2PA   3P  ...  draft_number  \
# 0   24  20.3  81  81  3054  789  1613  657  1229  132  ...             1
# 1   28  19.3  76  76  2877  765  1354  662  1100  103  ...             1
# 2   25  19.2  81  81  3122  849  1688  657  1197  192  ...             2
# 3   24  18.9  81  81  3119  731  1433  592  1099  139  ...             2
# 4   25  18.5  76  76  2966  768  1528  639  1141  129  ...             1
#
#     pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct
# 0  28.4  7.6  7.2        14.7     0.042     0.189    0.334   0.591    0.365
# 1  26.8  8.0  7.3        14.1     0.044     0.208    0.298   0.640    0.344
# 2  32.0  7.4  5.5         8.0     0.022     0.184    0.327   0.635    0.259
# 3  28.1  7.9  4.6        12.7     0.018     0.201    0.298   0.647    0.213
# 4  29.7  7.3  8.6        10.8     0.030     0.185    0.333   0.604    0.398
#
# [5 rows x 42 columns]

# %%
# Create our target
y = nba_players_df['MPPG'] #.map({'Successful': 1, 'Not Successful':0})

# %%
model = sm.OLS(y, X)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   MPPG   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          7.442e+04
# Date:                Fri, 08 Jan 2021   Prob (F-statistic):                        0.00
# Time:                        20:53:08   Log-Likelihood:                         -12866.
# No. Observations:                8102   AIC:                                  2.581e+04
# Df Residuals:                    8063   BIC:                                  2.608e+04
# Df Model:                          39
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Age                  0.0218      0.003      6.599      0.000       0.015       0.028
# WS                   0.1334      0.020      6.633      0.000       0.094       0.173
# G                   -0.0456      0.002    -27.314      0.000      -0.049      -0.042
# GS                  -0.0042      0.001     -3.983      0.000      -0.006      -0.002
# MP                   0.0123    9.8e-05    125.304      0.000       0.012       0.012
# FG                  -0.0037      0.000    -10.972      0.000      -0.004      -0.003
# FGA                  0.0030      0.000      7.039      0.000       0.002       0.004
# 2P                  -0.0019      0.001     -1.735      0.083      -0.004       0.000
# 2PA                  0.0026      0.000      5.881      0.000       0.002       0.004
# 3P                  -0.0017      0.001     -1.616      0.106      -0.004       0.000
# 3PA                  0.0004      0.001      0.609      0.543      -0.001       0.002
# FT                  -0.0052      0.001     -4.913      0.000      -0.007      -0.003
# FTA                  0.0046      0.001      5.170      0.000       0.003       0.006
# ORB                 -0.9954      0.841     -1.184      0.236      -2.643       0.652
# DRB                 -0.9967      0.841     -1.186      0.236      -2.644       0.651
# TRB                  0.9752      0.841      1.160      0.246      -0.672       2.623
# AST                 -0.0225      0.001    -35.550      0.000      -0.024      -0.021
# STL                 -0.0024      0.001     -2.522      0.012      -0.004      -0.001
# BLK                 -0.0013      0.001     -1.843      0.065      -0.003    8.48e-05
# TOV                  0.0086      0.001      8.170      0.000       0.007       0.011
# PF                   0.0025      0.001      4.661      0.000       0.001       0.004
# PTS                 -0.0142      0.001    -22.406      0.000      -0.015      -0.013
# FG%                 -1.2841      0.764     -1.681      0.093      -2.782       0.213
# 2P%                  0.5411      0.270      2.006      0.045       0.012       1.070
# 3P%                  0.3862      0.119      3.240      0.001       0.153       0.620
# eFG%                 2.9399      0.803      3.660      0.000       1.365       4.515
# FT%                  1.2481      0.103     12.079      0.000       1.046       1.451
# TS%                  4.9050      0.745      6.582      0.000       3.444       6.366
# player_height_cm    -0.0070      0.003     -2.280      0.023      -0.013      -0.001
# player_weight_kg    -0.0021      0.002     -0.984      0.325      -0.006       0.002
# draft_year           0.0042      0.000     15.660      0.000       0.004       0.005
# draft_round         -0.1007      0.044     -2.308      0.021      -0.186      -0.015
# draft_number         0.0006      0.002      0.338      0.736      -0.003       0.004
# pts                  0.9530      0.016     58.493      0.000       0.921       0.985
# reb                  1.7543      0.030     58.577      0.000       1.696       1.813
# ast                  1.7457      0.047     37.407      0.000       1.654       1.837
# net_rating          -0.0059      0.001     -4.672      0.000      -0.008      -0.003
# oreb_pct            -8.4550      0.542    -15.611      0.000      -9.517      -7.393
# dreb_pct            -8.6442      0.370    -23.382      0.000      -9.369      -7.919
# usg_pct            -11.9760      0.453    -26.411      0.000     -12.865     -11.087
# ts_pct              -9.0508      0.431    -20.980      0.000      -9.896      -8.205
# ast_pct             -5.9357      0.359    -16.540      0.000      -6.639      -5.232
# ==============================================================================
# Omnibus:                     3685.752   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           343255.173
# Skew:                           1.253   Prob(JB):                         0.00
# Kurtosis:                      34.789   Cond. No.                     1.05e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.96e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
